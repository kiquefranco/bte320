# %% [markdown]
# <a href="https://colab.research.google.com/github/kiquefranco/bte320/blob/main/InClassAssignmnets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In Class Assignmnet #1

# %%
Sales = int(input("Enter the total sales: "))
print(f"Total Sales: {Sales}")
COGS = 4800
GP = Sales - COGS
print(f"Gross Profit: {GP}")
TaxRate = float(input("Enter Tax Rate: "))
print(f"Tax Rate: {TaxRate}")
print(f"Cost of Goods Sold: {COGS}")
Tax = TaxRate * GP
print(f"Total Taxes: {Tax}")
NI = GP - Tax
print(f"Net Income: {NI}")
# Out:
# Enter the total sales: 12000
# Total Sales: 12000
# Gross Profit: 7200
# Enter Tax Rate: .05
# Tax Rate: 0.05
# Cost of Goods Sold: 4800
# Total Taxes: 360.0
# Net Income: 6840.0

# %% [markdown]
# In Class Assignment #2

# %%
x = float(input("Enter the first number: "))
y = float(input("Enter the second number: "))
op = input("Enter the operator: ")

if op == "+":
  answer = x + y
elif op == "-":
  answer = x - y
elif op == "*":
  answer = x * y
elif op == "/":
  answer = x / y
elif op == "//":
  answer = x // y
elif op == "**":
  answer = x ** y
elif op == "%":
  answer = x % y
else:
  print("Invalid Operator")
print(answer)
# Out:
# Enter the first number: 2
# Enter the second number: 4
# Enter the operator: //
# 0.0

# %% [markdown]
# In Class Assignmnet #3

# %%
flatfee = 5
hourly = 2.5
print("Hours|Total Fee")

for hours in range(1,9,1):
  fee = flatfee + (hours*hourly)
  if fee > 20:
    print(f"   {hours} | 20")
  elif fee < 10:
    print(f"   {hours} | 10")
  else:
    print(f"   {hours} | {fee}")
# Out:
# Hours|Total Fee
#    1 | 10
#    2 | 10.0
#    3 | 12.5
#    4 | 15.0
#    5 | 17.5
#    6 | 20.0
#    7 | 20
#    8 | 20

# %% [markdown]
# In Class Assignmnet #4

# %%
ticket = 10
print(f"Ad$ | Profit")

for ads in range(0,201,25):
  addattended = (2 * (ads**.5))
  totalattended = addattended + 20
  revenue = totalattended * ticket
  costs = ads + 200
  profit = round(revenue - costs)

  print(f" {ads} | {profit}")
# Out:
# Ad$ | Profit
#  0 | 0
#  25 | 75
#  50 | 91
#  75 | 98
#  100 | 100
#  125 | 99
#  150 | 95
#  175 | 90
#  200 | 83

# %% [markdown]
# In Class Assignment #5

# %%
flatfee = 5
hourly = 2.5
print("Hours|Total Fee")

hours = 1
while hours < 9:
  fee = flatfee + (hours*hourly)
  if fee > 20:
    print(f"   {hours} | 20")
  elif fee < 10:
    print(f"   {hours} | 10")
  else:
    print(f"   {hours} | {fee}")
  hours += 1
# Out:
# Hours|Total Fee
#    1 | 10
#    2 | 10.0
#    3 | 12.5
#    4 | 15.0
#    5 | 17.5
#    6 | 20.0
#    7 | 20
#    8 | 20

# %%
import math

ticket = 10
print(f"Ad$ | Profit")


ads = 0
while ads < 201:
  addattended = (2 * (ads**.5))
  totalattended = addattended + 20
  revenue = totalattended * ticket
  costs = ads + 200
  profit = round(revenue - costs)

  print(f" {ads} | {profit}")
  ads += 25
# Out:
# Ad$ | Profit
#  0 | 0
#  25 | 75
#  50 | 91
#  75 | 98
#  100 | 100
#  125 | 99
#  150 | 95
#  175 | 90
#  200 | 83

# %% [markdown]
# In Class Assignment #6

# %%
import random

play = input("Do you want to play? (y/n): ")

while play == 'y':
  play = input("Choose rock, paper, or scissors: ").lower()
  computer = random.choice(['rock','paper','scissors'])
  print(f"Computer chose {computer}")

  if player == computer:
    print("Draw")

  elif (
      player == 'rock' and computer == 'scissors' or
      player == 'paper' and computer == 'rock' or
      player == 'scissors' and computer == 'paper'
  ):
    print("You win")
  else:
    print("You lose")

  play = input("Do you want to continue playing? (y/n): ")
# Out:
# Computer chose scissors
# You lose
# Computer chose paper
# Draw

# %% [markdown]
# In Class Assignment #7

# %%
numbers = []

while True:
    user = float(input("Enter a number (enter 0 to stop): "))
    if user == 0:
        break
    numbers.append(user)

numbers.sort(reverse=True)
print("Numbers in descending order:", numbers)
# Out:
# Enter a number (enter 0 to stop): 4
# Enter a number (enter 0 to stop): 8
# Enter a number (enter 0 to stop): 4
# Enter a number (enter 0 to stop): 6
# Enter a number (enter 0 to stop): 1
# Enter a number (enter 0 to stop): 2
# Enter a number (enter 0 to stop): 0
# Numbers in descending order: [8.0, 6.0, 4.0, 4.0, 2.0, 1.0]

# %%
numbers = []

num = int(input("Enter a number:"))

while num != 0:
  numbers.append(num)
  num = int(input("Enter a number:"))

numbers.sort(reverse=True)
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4390/1779814533.py in <cell line: 0>()
#       1 numbers = []
#       2
# ----> 3 num = int(input("Enter a number:"))
#       4
#       5 while num != 0:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
weights = [10, 9.9, 10.1, 10.05]

print(__builtins__.sum(weights) / len(weights))
print(__builtins__.max(weights))
#Before I added the builtins it wasn't working I assume because I used
#One of these variables previously
# Out:
# 10.0125
# 10.1

# %% [markdown]
# In Class Assignmnet #8

# %%
d = {
    'P-01': 9.95,
    'P-02': 10.50,
}

user = input('Enter the product number: ')

if input == 'P-01':
  print(f"Price: {d['P-01']}")
elif user == 'P-02' :
    print(f"Price: {d['P-02']}")
else:
    print(f"{user} not found")
# Out:
# Enter the product number: P-02
# Price: 10.5

# %%
d = {
    'P-01': 9.95,
    'P-02': 10.50,
}

id = input('Enter the product number: ')

d.get(id,'Product Does not Exist')
# Out:
# Enter the product number: P-01
# 9.95

# %%
names = {}
n = 4

while True:
    name = input("Enter a name: ")
    if name in names:
      names[name] += 1
    else:
      names[name] = 1

    if name == "":
      break
print(names)
# Out:
# Enter a name: Luke
# Enter a name: Luke
# Enter a name: Luke
# Enter a name:
# {'Luke': 3, '': 1}

# %% [markdown]
# In Class Assignmnet #9

# %%
def totalfee(hours):

  flatfee = 5
  hourly = 2.5
  fee = flatfee + (hours * hourly)
  if fee > 20:
    return 20
  elif fee < 10:
    return 10
  else:
    return fee
hours = int(input("Enter the number of hours: "))
print(f"Total Fee: {totalfee(hours)}")
# Out:
# Enter the number of hours: 4
# Total Fee: 15.0

# %% [markdown]
# In Class #10

# %%
def reverse(s):
  if len(s) < 2:
    return s
  else:
    return s[-1] + reverse(s[:-1])

print(reverse('hello'))
# Out:
# olleh

# %% [markdown]
# Assignment #11

# %%
def checkEmailAddress():
  email = input("Enter an email account:")
  assert type(email) == str

  try:
    output = "@" in email and "." in email
    if output:
      return True
  except:
    return False

# %%
class Greeting:
  def __init__(self, first, last):
    self.first = first
    self.last = last

  def display(self, formal=False):
    if formal:
      print(f"{self.last}, {self.first}")
    else:
      print(f"{self.first}")

  def __str__(self):
    return "Instance of Class Greeting"

name = Greeting("Luke", "ZHou")
print(name)
name.display()
name.display(formal=True)
# Out:
# Instance of Class Greeting
# Luke
# ZHou, Luke

# %% [markdown]
# Assignmnet #12

# %%
def getValues (n):
  assert isinstance(n, int), "'n' must be an integer"
  items = []

  for i in range(n):
    items.append (float(input("Enter a value:")))

  if len(items) < 2:
    raise ValueError("the length of list 'items' cannot be < 2")
  return items


def calcAverage(alist):
  assert isinstance(alist, list), "'alist' must be a list"
  try:
    return sum(alist) / len(alist)
  except Exception as e:
    print(f"Error: {e}")


def main():
  n = int(input("'Enter a number of items to be added to the list: "))
  alist = getValues (n)
  avg = calcAverage(alist)
  print (f"Average weight: {avg} lbs.")
main ()
# Out:
# 'Enter a number of items to be added to the list: 5
# Enter a value:67
# Enter a value:98
# Enter a value:43
# Enter a value:47
# Enter a value:200
# Average weight: 91.0 lbs.

# %%
class Person:
    def __init__(self, first_name, last_name):
        self.first_name = first_name
        self.last_name = last_name

    def display(self, formal=False):
        if formal:
            print(f"{self.last_name}, {self.first_name}")
        else:
            print(self.first_name)

    def __str__(self):
        return f"Instance of class {self.__class__.__name__}"

name = Person ("John" , "Doe")
print(name)
name.display()
name.display(formal=True)

# %%
class Student:
  def __init__(self,name,number):
    self.__name = name
    self.number = number
    self.__courses = []

  def get_name(self):
    return self.__name

  def get_courses(self):
    return self.__courses

  def set_name(self, newName):
    self.__name = newName

  def __len__(self):
    return len(self.__courses)

  def enroll(self, newCourse):
    if newCourse not in self.couse:
      self.__courses.append(newCourse)
    else:
      print(f"{self.__name} is already enrolled in {newCourse}")

# %%
import math

class Point:
  def __init__(self, x, y):
    self.x = x
    self.y = y

  def distance(self, other):
    dx = (self.x - other.x) ** 2
    dy = (self.y - other.y) ** 2
    return (dx + dy) ** 0.5


class Rectangle:
  def __init__ (self):
    self.p1 = Point(0, 0)
    self.p2 = Point (3, 0)
    self.p3 = Point (0, 3)
    self.p4 = Point (3, 3)
    self.width = self.p1.distance(self.p2)
    self.height = self.p1.distance(self.p3)

  def area (self):
    return self.width * self.height


z = Rectangle()
print(z.area())
# Out:
# 9.0

# %%
class Employee:
    def __init__(self, name, wage, hours):
        self.name = name
        self.__hourly_wage = wage
        self.hours = hours

    def get_wage(self):
      return self.__hourly_wage

    def set_wage(self, wage):
      if newWage <= 0:
        print("Invalid wage")
      else:
        self.__hourly_wage = newWage

    def calculate_pay(self):
        return self.__hourly_wage * self.hours

    def display_info(self):
        print(f"Employee Name: {self.name}")
        print(f"Total Pay: ${self.calculate_pay()}")

class Manager(Employee):
    def __init__(self, name, hourly_wage, hours_worked, bonus):
        super().__init__(name, hourly_wage, hours_worked)
        self.bonus = bonus

    def calculate_pay(self):
        base_pay = super().calculate_pay()
        return base_pay + self.bonus

    def display_info(self):
        super().display_info()
        print(f"Bonus: ${self.bonus}")

print("Employee Information:")
employee = Employee("Jane Doe", 20.00, 40)
employee.display_info()

print("Manager Information:")
manager = Manager("John Smith", 30.00, 40, 500.00)
manager.display_info()
# Out:
# Employee Information:
# Employee Name: Jane Doe
# Total Pay: $800.0
# Manager Information:
# Employee Name: John Smith
# Total Pay: $1700.0
# Bonus: $500.0

# %%
class Employee:
    def __init__(self,name,wage,hours):
      self.name = name
      self.__hourly_wage = wage
      self.__hours = hours

    def get_wages(self):
      return self.__hourly_wage

    def set_wage(self, newWage):
      if newWage <= 0:
        print("Invalid wage")
      else:
        self.__hourly_wage = newWage

    def get_hours(self):
      return self.__hours

    def calculate_pay(self):
      return self.__hourly_wage * self.__hours

    def display_info(self):
      print(f"Employee Name: {self.name}\nHourly Wages: ${self.__hourly_wage}")

class Manager(Employee):
    def __init__(self,name,wage,hours,bonus):
      super().__init__(name,wage,hours)
      self.bonus = bonus

    def calculate_pay(self):
      return (1 + self.bonus) * self.get_wages() * self.get_hours()

employee = Employee("Bob", 50, 10)
manager = Manager("Alice", 100, 15, 0.2)
print(employee)
print(manager)
print()
print(f"Employee {employee.name} weekly salary is: ${employee.calculate_pay()}")
print(f"Manager {manager.name} weekly salary is: ${manager.calculate_pay()} that includes a {manager.bonus * 100}% bonus")
# Out:
# <__main__.Employee object at 0x7db86b8c3ef0>
# <__main__.Manager object at 0x7db86b90eb40>
#
# Employee Bob weekly salary is: $500
# Manager Alice weekly salary is: $1800.0 that includes a 20.0% bonus
